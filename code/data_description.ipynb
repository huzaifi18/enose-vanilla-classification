# %% [markdown]
# ## Menyiapkan semua library yang dibuthkan

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from baseline_correction import normalize_data_with_Baseline

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
A_df = pd.read_csv("../data_raw/A_1.csv")
B_df = pd.read_csv("../data_raw/B_1.csv")

# %% [markdown]
# # Sampel Data Visualization

# %% [markdown]
# ## Label A

# %%
att_names = ['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9', 'F10']

# %%
fig, ax=plt.subplots(figsize=(15, 7))
for i in att_names:
    plt.plot(A_df['time(s)'], A_df[i], label=i, linewidth=3)

plt.xlabel('Time (second)', fontsize=18)
plt.ylabel('Value', fontsize=18) # ganti satuan
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=18)

# Display the plot
plt.show()

# %%
A_df_crop = A_df[(A_df['time(s)'] >= 10) & (A_df['time(s)'] <= 30)]

fig, ax=plt.subplots(figsize=(15, 7))
for i in att_names:
    plt.plot(A_df_crop['time(s)'], A_df_crop[i], label=i, linewidth=3)

plt.xlabel('Time (second)', fontsize=18)
plt.ylabel('Value', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=18)

# Display the plot
plt.show()

# %%
# def normalize_data_with_Baseline(dataframe, atribute_names): # koreksi baseline, filename: '_A_*.csv'
#     baseline = []
#     baseline_df = dataframe[(dataframe['time(s)'] < 10)]
#     for cols in att_names:
#         baseline.append(baseline_df[cols].mean())
    
#     for cols_df, cols_baseline, in zip(att_names, baseline):
#         dataframe[cols_df] = dataframe[cols_df] - cols_baseline
#     return dataframe

# %%
A_df_processed = normalize_data_with_Baseline(A_df, att_names)

# %%
fig, ax=plt.subplots(figsize=(15, 7))
for i in att_names:
    plt.plot(A_df_processed['time(s)'], A_df_processed[i], label=i, linewidth=3)

plt.xlabel('Time (second)', fontsize=18)
plt.ylabel('Value', fontsize=18) # ganti satuan
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=18)
plt.grid()
plt.savefig("../Exp/Kurva Respon Sensor Label A.png", dpi=300)

# Display the plot
plt.show()

# %% [markdown]
# ## Label B

# %%
fig, ax=plt.subplots(figsize=(15, 7))
for i in att_names:
    plt.plot(B_df['time(s)'], B_df[i], label=i, linewidth=3)

plt.xlabel('Time (second)', fontsize=18)
plt.ylabel('Value', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=18)

# Display the plot
plt.show()

# %%
B_df_crop = B_df[(B_df['time(s)'] >= 10) & (B_df['time(s)'] <= 30)]

fig, ax=plt.subplots(figsize=(15, 7))
for i in att_names:
    plt.plot(B_df_crop['time(s)'], B_df_crop[i], label=i, linewidth=3)

plt.xlabel('Time (second)', fontsize=18)
plt.ylabel('Value', fontsize=18)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=18)

# Display the plot
plt.show()

# %%
B_df_processed = normalize_data_with_Baseline(B_df, att_names)

# %%
fig, ax=plt.subplots(figsize=(15, 7))
for i in att_names:
    plt.plot(B_df_processed['time(s)'], B_df_processed[i], label=i, linewidth=3)

plt.xlabel('Time (second)', fontsize=18)
plt.ylabel('Value', fontsize=18) # ganti satuan
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=18)
plt.grid()
plt.savefig("../Exp/Kurva Respon Sensor Label B.png", dpi=300)

# Display the plot
plt.show()

# %% [markdown]
# # Statistics Description

# %%
# missing values detection
A_df.isna().sum() # label A
# Out:
# time(s)    0
# F1         0
# F2         0
# F3         0
# F4         0
# F5         0
# F6         0
# F7         0
# F8         0
# F9         0
# F10        0
# Temp       0
# Humid      0
# dtype: int64

# %%
B_df.isna().sum() # label B
# Out:
# time(s)    0
# F1         0
# F2         0
# F3         0
# F4         0
# F5         0
# F6         0
# F7         0
# F8         0
# F9         0
# F10        0
# Temp       0
# Humid      0
# dtype: int64

# %%
A_df.describe().T # statistics descriptive
# Out:
#           count        mean         std       min        25%        50%  \
# time(s)  2701.0  135.000000   77.985586   0.00000   67.50000  135.00000
# F1       2701.0  278.774707  359.991771  -4.64125   36.23375  108.48375
# F2       2701.0   43.989714   48.442790  -0.40750   10.96750   21.34250
# F3       2701.0    0.076024    2.813892  -4.16000   -2.41000   -0.16000
# F4       2701.0  232.573832  432.895366 -24.57875   -2.45375   33.79625
# F5       2701.0   72.837648  207.806278  -9.51250   -7.88750   -1.88750
# F6       2701.0   57.169208  141.350082  -6.84500   -3.72000    2.53000
# F7       2701.0    4.608077    5.525889  -0.71000    0.54000    2.41500
# F8       2701.0  519.730558  721.532926 -47.51375   10.98625  168.48625
# F9       2701.0  479.891748  502.790243 -17.26250  113.48750  257.36250
# F10      2701.0  473.606706  619.909331 -26.78625   70.08875  186.08875
# Temp     2701.0   36.002121    0.016254  35.95000   35.99000   36.00000
# ...

# %%
B_df.describe().T # statistics descriptive
# Out:
#           count        mean         std       min        25%        50%  \
# time(s)  2701.0  135.000000   77.985586   0.00000   67.50000  135.00000
# F1       2701.0  331.002364  417.625128  -3.73875   46.51125  135.01125
# F2       2701.0   67.623879   78.380713  -0.65375   14.97125   30.97125
# F3       2701.0    1.091060    3.160022  -3.29750   -1.54750    0.07750
# F4       2701.0  272.282719  482.152417 -27.75125   -3.62625   48.12375
# F5       2701.0   94.967650  271.337329 -16.12750  -12.37750   -3.37750
# F6       2701.0   65.713963  174.576156 -13.83500   -8.83500   -0.71000
# F7       2701.0    7.883519    7.077948  -0.24125    2.63375    5.38375
# F8       2701.0  630.075288  787.768830 -11.39625   52.47875  249.97875
# F9       2701.0  527.467624  535.339724  -2.07125  126.05375  296.55375
# F10      2701.0  531.680929  672.455940  -4.68500   71.81500  214.56500
# Temp     2701.0   37.011766    0.016681  36.96000   37.00000   37.02000
# ...

# %% [markdown]
# # Korelasi antar feature

# %% [markdown]
# ### Label A

# %%
A_df.corr()
# Out:
#           time(s)        F1        F2        F3        F4        F5        F6  \
# time(s)  1.000000 -0.695848 -0.662690 -0.857885 -0.645148 -0.514533 -0.554172
# F1      -0.695848  1.000000  0.958162  0.787676  0.924746  0.760907  0.801997
# F2      -0.662690  0.958162  1.000000  0.855591  0.792881  0.549343  0.606237
# F3      -0.857885  0.787676  0.855591  1.000000  0.583283  0.342139  0.400589
# F4      -0.645148  0.924746  0.792881  0.583283  1.000000  0.939207  0.962845
# F5      -0.514533  0.760907  0.549343  0.342139  0.939207  1.000000  0.996600
# F6      -0.554172  0.801997  0.606237  0.400589  0.962845  0.996600  1.000000
# F7      -0.746343  0.986648  0.922367  0.801586  0.942179  0.802148  0.840924
# F8      -0.739916  0.974420  0.905484  0.767328  0.959474  0.822695  0.862846
# F9      -0.729621  0.981161  0.920930  0.791960  0.944040  0.799976  0.840692
# F10     -0.706032  0.955657  0.859240  0.692770  0.984020  0.878645  0.913333
# ...

# %%
fig, ax = plt.subplots(figsize=(15,10));
sns.heatmap(A_df.corr(), cmap=plt.cm.PuBu, ax=ax, annot=True, fmt='.3g')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Label B

# %%
B_df.corr()
# Out:
#           time(s)        F1        F2        F3        F4        F5        F6  \
# time(s)  1.000000 -0.705265 -0.664630 -0.820785 -0.670584 -0.526491 -0.556730
# F1      -0.705265  1.000000  0.946805  0.859323  0.946092  0.795931  0.820782
# F2      -0.664630  0.946805  1.000000  0.924106  0.815485  0.571571  0.606673
# F3      -0.820785  0.859323  0.924106  1.000000  0.695872  0.434059  0.474036
# F4      -0.670584  0.946092  0.815485  0.695872  1.000000  0.932961  0.950463
# F5      -0.526491  0.795931  0.571571  0.434059  0.932961  1.000000  0.998231
# F6      -0.556730  0.820782  0.606673  0.474036  0.950463  0.998231  1.000000
# F7      -0.711075  0.990903  0.944526  0.883502  0.926703  0.769450  0.794941
# F8      -0.747512  0.980334  0.911692  0.852496  0.960187  0.811368  0.840750
# F9      -0.739767  0.984111  0.918089  0.866782  0.950077  0.799921  0.828502
# F10     -0.726251  0.970794  0.878653  0.797376  0.983175  0.862605  0.888478
# ...

# %%
fig, ax = plt.subplots(figsize=(15,10));
sns.heatmap(B_df.corr(), cmap=plt.cm.PuBu, ax=ax, annot=True, fmt='.3g')
# Out:
# <AxesSubplot:>
